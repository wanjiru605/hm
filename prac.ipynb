# %% [markdown]
# <a href="https://colab.research.google.com/github/wanjiru605/hm/blob/main/prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# welcome to this session

# %%
#fiiting simple linear regression using statsmodel package
import statsmodels.formula.api as smf
# use smf.ols function
lm = smf.ols(formula='weight ~ height', data=child).fit()
#to get coefficient estimates
gslm.params

# %% [markdown]
# ![simpone.png](data:image/png;base64,...)

# %% [markdown]
# practice
# ssss
